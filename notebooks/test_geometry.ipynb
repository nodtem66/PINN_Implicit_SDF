# %%
# %load_ext autoreload
# %autoreload 2
# Add parent directory into system path
import sys, os
sys.path.insert(1, os.path.abspath(os.path.normpath('..')))

from utils import geometry
from utils.external_import import igl
# Out:
# [pyigl_import] module igl not found. trying to import pyigl

# %%
mesh = geometry.Mesh(meshPath = '../datasets/box_1f0_gyroid_4pi.stl', doNormalize=True)
sdf = geometry.SDF(mesh)
geometry.importanceSamplingComparisonPlot(mesh, sdf)
geometry.QMCSamplingPlot(mesh, sdf)
