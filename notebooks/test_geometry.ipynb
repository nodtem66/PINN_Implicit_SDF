# %%
# %load_ext autoreload
# %autoreload 2
# Add parent directory into system path
import sys, os
sys.path.insert(1, os.path.abspath(os.path.normpath('..')))

from utils import geometry
from utils.libs import igl
# Out:
# C:\Users\Jirawat\Desktop\src\github\sdf\libigl-python-bindings\out\build\x64-Release

# %%
v, f = igl.read_triangle_mesh('../datasets/box_1.0_10K_1M.stl')

# %%
mesh = geometry.Mesh(meshPath = '../datasets/box_1.0_10K_1M.stl', doNormalize=True)
sdf = geometry.SDF(mesh)
geometry.importanceSamplingComparisonPlot(mesh, sdf)
